# %% [markdown]
# <a href="https://colab.research.google.com/github/shinebalance/DL_notes/blob/master/DeepLearningwithPython/8_5_welcome_to_GAN(20191125).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **"Deep Learning with Python" 8-5.GAN**
# ---
#
# ## 【目的】
# * GAN(Generative Adversarial Network)を動かしてみよう
#
# 訳書：https://book.mynavi.jp/ec/products/detail/id=90124  <br>
# 原著：https://www.manning.com/books/deep-learning-with-python
# <div align="center">
# <img src="https://images.manning.com/720/960/resize/book/7/65fca1c-6826-472d-bbea-c1d4a7b3c570/Chollet-DLP-HI.png" frameborder="0" width="110" height="125" scrolling="yes"></img>
# </div>
#
# ## 【備考】
# * 軽微な変更を除きほぼFrancois氏コードから変更ありません。
# * 最後のイテレーション完了に30分くらいかかります。
# * edited by @shinebalance
#
# > 元ネタはこちら
# > https://github.com/fchollet/deep-learning-with-python-notebooks/blob/master/8.5-introduction-to-gans.ipynb
#
# ---

# %%
import keras
keras.__version__
# Out:
# '2.2.5'

# %% [markdown]
# # Introduction to generative adversarial networks(著者解説,概ね本書とかぶる＆コードセル無いので省略)
#
# This notebook contains the second code sample found in Chapter 8, Section 5 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ---
# [...]

# %% [markdown]
# ## A schematic GAN implementation
#
#
# In what follows, we explain how to implement a GAN in Keras, in its barest form -- since GANs are quite advanced, diving deeply into the
# technical details would be out of scope for us. Our specific implementation will be a deep convolutional GAN, or DCGAN: a GAN where the
# generator and discriminator are deep convnets. In particular, it leverages a `Conv2DTranspose` layer for image upsampling in the generator.
#
# We will train our GAN on images from CIFAR10, a dataset of 50,000 32x32 RGB images belong to 10 classes (5,000 images per class). To make
# things even easier, we will only use images belonging to the class "frog".
#
# Schematically, our GAN looks like this:
#
# * A `generator` network maps vectors of shape `(latent_dim,)` to images of shape `(32, 32, 3)`.
# * A `discriminator` network maps images of shape (32, 32, 3) to a binary score estimating the probability that the image is real.
# * A `gan` network chains the generator and the discriminator together: `gan(x) = discriminator(generator(x))`. Thus this `gan` network maps
# latent space vectors to the discriminator's assessment of the realism of these latent vectors as decoded by the generator.
# * We train the discriminator using examples of real and fake images along with "real"/"fake" labels, as we would train any regular image
# classification model.
# * To train the generator, we use the gradients of the generator's weights with regard to the loss of the `gan` model. This means that, at
# every step, we move the weights of the generator in a direction that will make the discriminator more likely to classify as "real" the
# images decoded by the generator. I.e. we train the generator to fool the discriminator.

# %% [markdown]
# ## A bag of tricks
#
#
# Training GANs and tuning GAN implementations is notoriously difficult. There are a number of known "tricks" that one should keep in mind.
# Like most things in deep learning, it is more alchemy than science: these tricks are really just heuristics, not theory-backed guidelines.
# They are backed by some level of intuitive understanding of the phenomenon at hand, and they are known to work well empirically, albeit not
# necessarily in every context.
#
# Here are a few of the tricks that we leverage in our own implementation of a GAN generator and discriminator below. It is not an exhaustive
# list of GAN-related tricks; you will find many more across the GAN literature.
#
# * We use `tanh` as the last activation in the generator, instead of `sigmoid`, which would be more commonly found in other types of models.
# * We sample points from the latent space using a _normal distribution_ (Gaussian distribution), not a uniform distribution.
# * Stochasticity is good to induce robustness. Since GAN training results in a dynamic equilibrium, GANs are likely to get "stuck" in all sorts of ways.
# Introducing randomness during training helps prevent this. We introduce randomness in two ways: 1) we use dropout in the discriminator, 2)
# we add some random noise to the labels for the discriminator.
# * Sparse gradients can hinder GAN training. In deep learning, sparsity is often a desirable property, but not in GANs. There are two things
# that can induce gradient sparsity: 1) max pooling operations, 2) ReLU activations. Instead of max pooling, we recommend using strided
# convolutions for downsampling, and we recommend using a `LeakyReLU` layer instead of a ReLU activation. It is similar to ReLU but it
# relaxes sparsity constraints by allowing small negative activation values.
# * In generated images, it is common to see "checkerboard artifacts" caused by unequal coverage of the pixel space in the generator. To fix
# this, we use a kernel size that is divisible by the stride size, whenever we use a strided `Conv2DTranpose` or `Conv2D` in both the
# generator and discriminator.

# %% [markdown]
# # The generator(:Generatorの構築)
# memo: 32*32のインプットをCNNで畳み込んでから再度展開して画像を生成するNW。generator.summary()の結果をご参照。
# <br><br>
# First, we develop a `generator` model, which turns a vector (from the latent space -- during training it will sampled at random) into a
# candidate image. One of the many issues that commonly arise with GANs is that the generator gets stuck with generated images that look like
# noise. A possible solution is to use dropout on both the discriminator and generator.

# %%
import keras
from keras import layers
import numpy as np

latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

# First, transform the input into a 16x16 128-channels feature map
x = layers.Dense(128 * 16 * 16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

# Then, add a convolution layer
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Upsample to 32x32
x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

# Few more conv layers
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Produce a 32x32 1-channel feature map
x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 32768)             0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # The discriminatorgenerator(:Discriminator,判別者の構築)
# memo: 32*32のインプットをオーソドックスCNNで畳み込む分類のNW。generator.summary()の結果をご参照。
# <br><br>
# Then, we develop a `discriminator` model, that takes as input a candidate image (real or synthetic) and classifies it into one of two
# classes, either "generated image" or "real image that comes from the training set".

# %%
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

# One dropout layer - important trick!
x = layers.Dropout(0.4)(x)

# Classification layer
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

# To stabilize training, we use learning rate decay
# and gradient clipping (by value) in the optimizer.
discriminator_optimizer = keras.optimizers.RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # The adversarial network(:Adversarial(敵対的)ネットワーク)
# memo:Generatorを訓練する（Descriminatorをうまく騙せるようにする）ためのNW。ランダムノイズをインプットに、Generator→Descriminatorの結果が「本物の画像である」となるようにGeneratorの重み更新を行う。
# <br>
# ポイントとして、descriminatorの重みはこの段階では更新せず凍結する。このNWの訓練時にはインプットのラベルを「本物の画像である」として学習するので、合わせてDescriminatorまで重み更新を行ってしまうと、偽物の画像を訓練できないDescriminatorになってしまう。
# <br><br>
# Finally, we setup the GAN, which chains the generator and the discriminator. This is the model that, when trained, will move the generator
# in a direction that improves its ability to fool the discriminator. This model turns latent space points into a classification decision,
# "fake" or "real", and it is meant to be trained with labels that are always "these are real images". So training `gan` will updates the
# weights of `generator` in a way that makes `discriminator` more likely to predict "real" when looking at fake images. Very importantly, we
# set the discriminator to be frozen during training (non-trainable): its weights will not be updated when training `gan`. If the
# discriminator weights could be updated during this process, then we would be training the discriminator to always predict "real", which is
# not what we want!

# %%
# Set discriminator weights to non-trainable
# (will only apply to the `gan` model)
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %% [markdown]
# # How to train your(:GAN(DCGAN)の訓練)
# ## おまけ(1)(2)実行時は省略
#
# Now we can start training. To recapitulate, this is schematically what the training loop looks like:
#
# ```
# for each epoch:
#     * Draw random points in the latent space (random noise).
#     * Generate images with `generator` using this random noise.
#     * Mix the generated images with real ones.
#     * Train `discriminator` using these mixed images, with corresponding targets, either "real" (for the real images) or "fake" (for the generated images).
#     * Draw new random points in the latent space.
#     * Train `gan` using these random vectors, with targets that all say "these are real images". This will update the weights of the generator (only, since discriminator is frozen inside `gan`) to move them towards getting the discriminator to predict "these are real images" for generated images, i.e. this trains the generator to fool the discriminator.
# ```
#
# Let's implement it:

# %% [markdown]
# 上記解説。1エポックの中では以下の行程が行われている。
#  1. ランダムノイズを生成する
#  2. Generatorがランダムノイズで画像を生成する。
#  3. 本物の画像1枚と生成画像1枚をミックスする。
#  4. Descriminatorにこの2枚のイメージを渡して真贋判定を行わせる。
#  (おそらくこの段階でDescriminatorは真贋判定を元にバックプロパゲーションを行う。)
#  5. 新しいランダムノイズを生成する。
#  6. Adversarial NWにランダムノイズを「本物の画像である」とラベルづけして投入して訓練を行う。
#   この段階ではじめてGeneratorはバックプロパゲーションを行う。行程2の
#   画像生成ではバックプロパゲーションを行わないのがミソ。
#   <br>
#
# * GANのバランスを成立させるために、1エポックの中で上記のようなアイデアが盛り込まれているものと思われる。
# * 行程6の意味が発表者は最初わからず混乱したが、GeneratorとDescriminatorを擬人化して想像するとだいぶ理解しやすくなる。
#  * 行程6でGくんを訓練する際に、GくんがきちんとDくんを騙せるようになるためには、仮想のDくんのような存在を用意して、「Dくんだったら本物と判定するはず」という答えを元にバックプロパゲーションを行うしかない。でもこのタイミングで本物のDくんがGくんのやっている訓練を知ってしまっては意味がない。（だから凍結してもらう必要がある）
#   * 例えが下手ですみません(´・ω・`)

# %%
import os
from keras.preprocessing import image

# Load CIFAR10 data
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# Select frog images (class 6)
x_train = x_train[y_train.flatten() == 6]

# Normalize data
x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32') / 255.

iterations = 10000
batch_size = 20
# save_dir = '/home/ubuntu/gan_images/'
# shinebalance memo: francoisはcolabを使っていないので以下の通り変更
# !mkdir gan_images
save_dir = './gan_images/'

# Start training loop
start = 0
for step in range(iterations):
    # Sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Decode them to fake images
    generated_images = generator.predict(random_latent_vectors)

    # Combine them with real images
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])

    # Assemble labels discriminating real from fake images
    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    # Add random noise to the labels - important trick!
    labels += 0.05 * np.random.random(labels.shape)

    # Train the discriminator
    d_loss = discriminator.train_on_batch(combined_images, labels)

    # sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Assemble labels that say "all real images"
    misleading_targets = np.zeros((batch_size, 1))

    # Train the generator (via the gan model,
    # where the discriminator weights are frozen)
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    
    start += batch_size
    if start > len(x_train) - batch_size:
      start = 0

    # Occasionally save / plot
    if step % 100 == 0:
        # Save model weights
        gan.save_weights('gan.h5')

        # Print metrics
        print('discriminator loss at step %s: %s' % (step, d_loss))
        print('adversarial loss at step %s: %s' % (step, a_loss))

        # Save one generated image
        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

        # Save one real image, for comparison
        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# discriminator loss at step 0: 0.68588936
# adversarial loss at step 0: 0.67434275
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# discriminator loss at step 100: 0.794491
# adversarial loss at step 100: 0.7227358
# discriminator loss at step 200: 0.79615724
# adversarial loss at step 200: 0.8055228
# discriminator loss at step 300: 0.7269114
# adversarial loss at step 300: 0.73236656
# discriminator loss at step 400: 0.8691468
# adversarial loss at step 400: 0.69040716
# discriminator loss at step 500: 0.6955229
# adversarial loss at step 500: 0.7364869
# discriminator loss at step 600: 0.6996504
# adversarial loss at step 600: 0.7680569
# discriminator loss at step 700: 0.7092838
# adversarial loss at step 700: 0.7583023
# discriminator loss at step 800: 0.71960175
# adversarial loss at step 800: 0.7448987
# discriminator loss at step 900: 0.6968948
# adversarial loss at step 900: 0.73748595
# discriminator loss at step 1000: 0.7031018
# adversarial loss at step 1000: 0.76199883
# discriminator loss at step 1100: 0.6874646
# adversarial loss at step 1100: 0.7599869
# discriminator loss at step 1200: 0.69947827
# adversarial loss at step 1200: 0.73746765
# discriminator loss at step 1300: 0.6956231
# adversarial loss at step 1300: 0.7789762
# discriminator loss at step 1400: 0.69328636
# adversarial loss at step 1400: 0.7489044
# discriminator loss at step 1500: 0.6980772
# adversarial loss at step 1500: 0.8308295
# discriminator loss at step 1600: 0.6811009
# adversarial loss at step 1600: 0.7789127
# discriminator loss at step 1700: 0.7003845
# adversarial loss at step 1700: 0.7424134
# discriminator loss at step 1800: 0.7227766
# adversarial loss at step 1800: 0.7514974
# discriminator loss at step 1900: 0.7113284
# adversarial loss at step 1900: 0.73062456
# discriminator loss at step 2000: 0.6954635
# adversarial loss at step 2000: 0.73328674
# discriminator loss at step 2100: 0.68312037
# adversarial loss at step 2100: 0.7886572
# discriminator loss at step 2200: 0.70496005
# adversarial loss at step 2200: 0.75229406
# discriminator loss at step 2300: 0.9764633
# adversarial loss at step 2300: 0.7295033
# discriminator loss at step 2400: 0.71644104
# adversarial loss at step 2400: 0.75324696
# discriminator loss at step 2500: 0.71223897
# adversarial loss at step 2500: 0.74658155
# discriminator loss at step 2600: 0.80555093
# adversarial loss at step 2600: 0.7987132
# discriminator loss at step 2700: 0.67607975
# adversarial loss at step 2700: 0.72338057
# discriminator loss at step 2800: 0.6795138
# adversarial loss at step 2800: 0.7405633
# discriminator loss at step 2900: 0.6939747
# adversarial loss at step 2900: 0.74862635
# discriminator loss at step 3000: 0.71285534
# adversarial loss at step 3000: 0.7375669
# discriminator loss at step 3100: 0.6932017
# adversarial loss at step 3100: 0.7488125
# discriminator loss at step 3200: 0.691281
# adversarial loss at step 3200: 0.74954647
# discriminator loss at step 3300: 0.7117607
# adversarial loss at step 3300: 0.75292957
# discriminator loss at step 3400: 0.70488566
# adversarial loss at step 3400: 0.72848463
# discriminator loss at step 3500: 0.7111696
# adversarial loss at step 3500: 1.786882
# discriminator loss at step 3600: 0.7035584
# adversarial loss at step 3600: 0.7276432
# discriminator loss at step 3700: 0.6982173
# adversarial loss at step 3700: 0.7742012
# discriminator loss at step 3800: 0.68227196
# adversarial loss at step 3800: 0.7704542
# discriminator loss at step 3900: 0.7034546
# adversarial loss at step 3900: 0.77696335
# discriminator loss at step 4000: 0.6972219
# adversarial loss at step 4000: 0.7717364
# discriminator loss at step 4100: 0.70194215
# adversarial loss at step 4100: 0.77910215
# discriminator loss at step 4200: 1.075943
# adversarial loss at step 4200: 0.8237669
# discriminator loss at step 4300: 0.70440614
# adversarial loss at step 4300: 0.74798125
# discriminator loss at step 4400: 0.6978654
# adversarial loss at step 4400: 0.7591153
# discriminator loss at step 4500: 0.69375896
# adversarial loss at step 4500: 0.7523492
# discriminator loss at step 4600: 0.70946103
# adversarial loss at step 4600: 0.7658337
# discriminator loss at step 4700: 0.6930277
# adversarial loss at step 4700: 0.79211307
# discriminator loss at step 4800: 0.6907643
# adversarial loss at step 4800: 0.7030647
# discriminator loss at step 4900: 0.69491136
# adversarial loss at step 4900: 0.72368455
# discriminator loss at step 5000: 0.6788541
# adversarial loss at step 5000: 0.73221844
# discriminator loss at step 5100: 0.7066685
# adversarial loss at step 5100: 0.7471338
# discriminator loss at step 5200: 0.6969848
# adversarial loss at step 5200: 0.51374644
# discriminator loss at step 5300: 0.6964088
# adversarial loss at step 5300: 0.78340495
# discriminator loss at step 5400: 0.69073206
# adversarial loss at step 5400: 0.7549669
# discriminator loss at step 5500: 0.703217
# adversarial loss at step 5500: 0.7713319
# discriminator loss at step 5600: 0.69340944
# adversarial loss at step 5600: 0.738748
# discriminator loss at step 5700: 0.6906034
# adversarial loss at step 5700: 0.7611969
# discriminator loss at step 5800: 0.7109366
# adversarial loss at step 5800: 0.8887579
# discriminator loss at step 5900: 0.6902809
# adversarial loss at step 5900: 0.77740604
# discriminator loss at step 6000: 0.6990949
# adversarial loss at step 6000: 0.7429905
# discriminator loss at step 6100: 0.6960653
# adversarial loss at step 6100: 0.7530894
# discriminator loss at step 6200: 0.69167215
# adversarial loss at step 6200: 0.7746376
# discriminator loss at step 6300: 0.69634515
# adversarial loss at step 6300: 0.7481549
# discriminator loss at step 6400: 0.6872006
# adversarial loss at step 6400: 0.79012406
# discriminator loss at step 6500: 0.67448634
# adversarial loss at step 6500: 0.78491443
# discriminator loss at step 6600: 0.7023385
# adversarial loss at step 6600: 0.7481798
# discriminator loss at step 6700: 0.69581056
# adversarial loss at step 6700: 0.7737886
# discriminator loss at step 6800: 0.69057626
# adversarial loss at step 6800: 0.80005133
# discriminator loss at step 6900: 0.6839507
# adversarial loss at step 6900: 0.81217873
# discriminator loss at step 7000: 0.6770238
# adversarial loss at step 7000: 0.7669519
# discriminator loss at step 7100: 0.69087875
# adversarial loss at step 7100: 0.74598294
# discriminator loss at step 7200: 0.69012725
# adversarial loss at step 7200: 0.79319715
# discriminator loss at step 7300: 0.684513
# adversarial loss at step 7300: 0.8492112
# discriminator loss at step 7400: 0.69564784
# adversarial loss at step 7400: 0.72820747
# discriminator loss at step 7500: 0.70310277
# adversarial loss at step 7500: 0.75297254
# discriminator loss at step 7600: 0.7028098
# adversarial loss at step 7600: 0.8466468
# discriminator loss at step 7700: 0.71118796
# adversarial loss at step 7700: 0.87410194
# discriminator loss at step 7800: 0.6777671
# adversarial loss at step 7800: 0.789024
# discriminator loss at step 7900: 0.7013873
# adversarial loss at step 7900: 0.75423515
# discriminator loss at step 8000: 0.68792295
# adversarial loss at step 8000: 0.808829
# discriminator loss at step 8100: 0.68599945
# adversarial loss at step 8100: 0.80098087
# discriminator loss at step 8200: 0.7581368
# adversarial loss at step 8200: 0.78609836
# discriminator loss at step 8300: 0.6804896
# adversarial loss at step 8300: 0.7389072
# discriminator loss at step 8400: 0.67212826
# adversarial loss at step 8400: 0.74201775
# discriminator loss at step 8500: 0.70550454
# adversarial loss at step 8500: 0.8679698
# discriminator loss at step 8600: 0.6858083
# adversarial loss at step 8600: 0.7985171
# discriminator loss at step 8700: 0.73106
# adversarial loss at step 8700: 0.779786
# discriminator loss at step 8800: 0.8175852
# adversarial loss at step 8800: 1.0117557
# discriminator loss at step 8900: 0.67924273
# adversarial loss at step 8900: 0.7340296
# discriminator loss at step 9000: 0.6630326
# adversarial loss at step 9000: 0.74680203
# discriminator loss at step 9100: 0.6971406
# adversarial loss at step 9100: 0.84695387
# discriminator loss at step 9200: 0.7209029
# adversarial loss at step 9200: 0.7964155
# discriminator loss at step 9300: 0.68309015
# adversarial loss at step 9300: 0.8642195
# discriminator loss at step 9400: 0.6903831
# adversarial loss at step 9400: 0.7374791
# discriminator loss at step 9500: 0.6759359
# adversarial loss at step 9500: 0.74275994
# discriminator loss at step 9600: 0.693612
# adversarial loss at step 9600: 0.78080285
# discriminator loss at step 9700: 0.6996015
# adversarial loss at step 9700: 0.8004095
# discriminator loss at step 9800: 0.6609896
# adversarial loss at step 9800: 0.81789464
# discriminator loss at step 9900: 0.67574424
# adversarial loss at step 9900: 0.6395844

# %% [markdown]
# Let's display a few of our fake images:

# %%
import matplotlib.pyplot as plt

# Sample random points in the latent space
random_latent_vectors = np.random.normal(size=(10, latent_dim))

# Decode them to fake images
generated_images = generator.predict(random_latent_vectors)

for i in range(generated_images.shape[0]):
    img = image.array_to_img(generated_images[i] * 255., scale=False)
    plt.figure()
    plt.imshow(img)
    
plt.show()

# %% [markdown]
# Froggy with some pixellated artifacts.

# %% [markdown]
# # おまけ(1)：せっかくなので他のクラスでもやってみた
#
# * CIFAR-10:https://www.cs.toronto.edu/~kriz/cifar.html
# * 各クラス：https://uchidama.hatenablog.com/entry/2018/01/11/065000

# %%
import os
from keras.preprocessing import image

# Load CIFAR10 data
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# Select frog images (class 0:飛行機)
x_train = x_train[y_train.flatten() == 0]

# Normalize data
x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32') / 255.

iterations = 10000
batch_size = 20
# !mkdir gan_images
save_dir = './gan_images/'

# Start training loop
start = 0
for step in range(iterations):
    # Sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Decode them to fake images
    generated_images = generator.predict(random_latent_vectors)

    # Combine them with real images
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])

    # Assemble labels discriminating real from fake images
    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    # Add random noise to the labels - important trick!
    labels += 0.05 * np.random.random(labels.shape)

    # Train the discriminator
    d_loss = discriminator.train_on_batch(combined_images, labels)

    # sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Assemble labels that say "all real images"
    misleading_targets = np.zeros((batch_size, 1))

    # Train the generator (via the gan model,
    # where the discriminator weights are frozen)
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    
    start += batch_size
    if start > len(x_train) - batch_size:
      start = 0

    # Occasionally save / plot
    if step % 100 == 0:
        # Save model weights
        gan.save_weights('gan.h5')

        # Print metrics
        print('discriminator loss at step %s: %s' % (step, d_loss))
        print('adversarial loss at step %s: %s' % (step, a_loss))

        # Save one generated image
        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'generated_airplane' + str(step) + '.png'))

        # Save one real image, for comparison
        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'real_airplane' + str(step) + '.png'))
# Out:
# mkdir: cannot create directory ‘gan_images’: File exists
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# discriminator loss at step 0: 0.6726923
# adversarial loss at step 0: 0.63904446
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# discriminator loss at step 100: 0.6402358
# adversarial loss at step 100: 0.8380493
# discriminator loss at step 200: 0.6832668
# adversarial loss at step 200: 0.8563612
# discriminator loss at step 300: 0.7272579
# adversarial loss at step 300: 0.764741
# discriminator loss at step 400: 0.69783956
# adversarial loss at step 400: 0.7252638
# discriminator loss at step 500: 0.695761
# adversarial loss at step 500: 0.7910141
# discriminator loss at step 600: 0.69574153
# adversarial loss at step 600: 0.6631329
# discriminator loss at step 700: 0.70765424
# adversarial loss at step 700: 0.72920644
# discriminator loss at step 800: 0.7049211
# adversarial loss at step 800: 0.74325174
# discriminator loss at step 900: 0.7085574
# adversarial loss at step 900: 0.7674163
# discriminator loss at step 1000: 0.69524914
# adversarial loss at step 1000: 0.7683827
# discriminator loss at step 1100: 0.6857377
# adversarial loss at step 1100: 0.7437205
# discriminator loss at step 1200: 0.6937304
# adversarial loss at step 1200: 0.7676202
# discriminator loss at step 1300: 0.709138
# adversarial loss at step 1300: 0.76589715
# discriminator loss at step 1400: 0.69567573
# adversarial loss at step 1400: 0.76426446
# discriminator loss at step 1500: 0.6921152
# adversarial loss at step 1500: 0.72492504
# discriminator loss at step 1600: 0.71536505
# adversarial loss at step 1600: 0.7557666
# discriminator loss at step 1700: 0.6996342
# adversarial loss at step 1700: 0.7132867
# discriminator loss at step 1800: 0.6893685
# adversarial loss at step 1800: 0.7346276
# discriminator loss at step 1900: 0.73024994
# adversarial loss at step 1900: 0.80131894
# discriminator loss at step 2000: 0.69880486
# adversarial loss at step 2000: 0.73211807
# discriminator loss at step 2100: 0.6979653
# adversarial loss at step 2100: 0.8029138
# discriminator loss at step 2200: 0.6978556
# adversarial loss at step 2200: 0.6973256
# discriminator loss at step 2300: 0.6904092
# adversarial loss at step 2300: 0.7850426
# discriminator loss at step 2400: 0.6913377
# adversarial loss at step 2400: 0.73870265
# discriminator loss at step 2500: 0.69003904
# adversarial loss at step 2500: 0.7333809
# discriminator loss at step 2600: 0.7099966
# adversarial loss at step 2600: 0.71044546
# discriminator loss at step 2700: 0.6969715
# adversarial loss at step 2700: 0.853473
# discriminator loss at step 2800: 0.69964373
# adversarial loss at step 2800: 0.7426894
# discriminator loss at step 2900: 0.68882114
# adversarial loss at step 2900: 0.76480544
# discriminator loss at step 3000: 0.66605556
# adversarial loss at step 3000: 0.65074396
# discriminator loss at step 3100: 0.69945896
# adversarial loss at step 3100: 0.73710215
# discriminator loss at step 3200: 0.680342
# adversarial loss at step 3200: 0.7527458
# discriminator loss at step 3300: 0.69282037
# adversarial loss at step 3300: 0.8251541
# discriminator loss at step 3400: 0.68140745
# adversarial loss at step 3400: 0.78284556
# discriminator loss at step 3500: 0.69540817
# adversarial loss at step 3500: 0.7796319
# discriminator loss at step 3600: 0.68015414
# adversarial loss at step 3600: 0.6704669
# discriminator loss at step 3700: 0.68317544
# adversarial loss at step 3700: 0.81023777
# discriminator loss at step 3800: 0.6863093
# adversarial loss at step 3800: 0.75036037
# discriminator loss at step 3900: 0.6983974
# adversarial loss at step 3900: 0.79264426
# discriminator loss at step 4000: 0.683756
# adversarial loss at step 4000: 0.79491276
# discriminator loss at step 4100: 0.6824507
# adversarial loss at step 4100: 0.8009676
# discriminator loss at step 4200: 0.6937763
# adversarial loss at step 4200: 0.7763139
# discriminator loss at step 4300: 0.7177537
# adversarial loss at step 4300: 0.7492917
# discriminator loss at step 4400: 0.69514763
# adversarial loss at step 4400: 0.7702055
# discriminator loss at step 4500: 0.69191706
# adversarial loss at step 4500: 0.78635365
# discriminator loss at step 4600: 0.6974156
# adversarial loss at step 4600: 0.73563385
# discriminator loss at step 4700: 0.69298595
# adversarial loss at step 4700: 0.8007536
# discriminator loss at step 4800: 0.72035134
# adversarial loss at step 4800: 0.7217959
# discriminator loss at step 4900: 0.70078075
# adversarial loss at step 4900: 0.8582634
# discriminator loss at step 5000: 0.68826467
# adversarial loss at step 5000: 0.798849
# discriminator loss at step 5100: 0.777493
# adversarial loss at step 5100: 0.7779916
# discriminator loss at step 5200: 0.6860715
# adversarial loss at step 5200: 0.79621553
# discriminator loss at step 5300: 0.7101356
# adversarial loss at step 5300: 0.8277257
# discriminator loss at step 5400: 0.7400385
# adversarial loss at step 5400: 0.84898776
# discriminator loss at step 5500: 0.7194334
# adversarial loss at step 5500: 0.96161145
# discriminator loss at step 5600: 0.6714808
# adversarial loss at step 5600: 0.6798552
# discriminator loss at step 5700: 0.6745504
# adversarial loss at step 5700: 0.3377381
# discriminator loss at step 5800: 0.7023819
# adversarial loss at step 5800: 0.7436118
# discriminator loss at step 5900: 0.700583
# adversarial loss at step 5900: 0.75825596
# discriminator loss at step 6000: 0.6848937
# adversarial loss at step 6000: 0.7887124
# discriminator loss at step 6100: 0.686179
# adversarial loss at step 6100: 0.66981035
# discriminator loss at step 6200: 0.7202433
# adversarial loss at step 6200: 0.7246021
# discriminator loss at step 6300: 0.7098557
# adversarial loss at step 6300: 0.74835145
# discriminator loss at step 6400: 0.67588127
# adversarial loss at step 6400: 0.30911666
# discriminator loss at step 6500: 0.69949496
# adversarial loss at step 6500: 0.7588699
# discriminator loss at step 6600: 0.7062909
# adversarial loss at step 6600: 0.7352998
# discriminator loss at step 6700: 0.6952913
# adversarial loss at step 6700: 0.78338885
# discriminator loss at step 6800: 0.7719866
# adversarial loss at step 6800: 0.9710971
# discriminator loss at step 6900: 0.73116076
# adversarial loss at step 6900: 0.741988
# discriminator loss at step 7000: 0.6920028
# adversarial loss at step 7000: 0.7374829
# discriminator loss at step 7100: 0.7067052
# adversarial loss at step 7100: 0.588417
# discriminator loss at step 7200: 0.6826854
# adversarial loss at step 7200: 0.79097575
# discriminator loss at step 7300: 0.7187797
# adversarial loss at step 7300: 0.7468124
# discriminator loss at step 7400: 0.7010641
# adversarial loss at step 7400: 0.7933377
# discriminator loss at step 7500: 0.7171992
# adversarial loss at step 7500: 0.7177344
# discriminator loss at step 7600: 0.6956813
# adversarial loss at step 7600: 0.7530304
# discriminator loss at step 7700: 0.72085273
# adversarial loss at step 7700: 0.80183077
# discriminator loss at step 7800: 0.69874513
# adversarial loss at step 7800: 0.7850917
# discriminator loss at step 7900: 0.72268623
# adversarial loss at step 7900: 1.0557264
# discriminator loss at step 8000: 0.7056944
# adversarial loss at step 8000: 0.8240712
# discriminator loss at step 8100: 0.7196951
# adversarial loss at step 8100: 0.80584824
# discriminator loss at step 8200: 0.69777596
# adversarial loss at step 8200: 0.6891872
# discriminator loss at step 8300: 0.69734275
# adversarial loss at step 8300: 0.6659425
# discriminator loss at step 8400: 0.7080697
# adversarial loss at step 8400: 0.8227126
# discriminator loss at step 8500: 0.69707
# adversarial loss at step 8500: 0.77662325
# discriminator loss at step 8600: 0.69781816
# adversarial loss at step 8600: 0.76261616
# discriminator loss at step 8700: 0.7006826
# adversarial loss at step 8700: 0.6957251
# discriminator loss at step 8800: 0.7023496
# adversarial loss at step 8800: 0.74627113
# discriminator loss at step 8900: 0.689875
# adversarial loss at step 8900: 0.8046303
# discriminator loss at step 9000: 0.68354803
# adversarial loss at step 9000: 0.78530145
# discriminator loss at step 9100: 0.7012464
# adversarial loss at step 9100: 0.7446416
# discriminator loss at step 9200: 0.70900905
# adversarial loss at step 9200: 0.7789024
# discriminator loss at step 9300: 0.5489334
# adversarial loss at step 9300: 2.132357
# discriminator loss at step 9400: 0.690292
# adversarial loss at step 9400: 0.75803983
# discriminator loss at step 9500: 0.69459355
# adversarial loss at step 9500: 0.82988626
# discriminator loss at step 9600: 0.6937106
# adversarial loss at step 9600: 0.7836484
# discriminator loss at step 9700: 0.6895483
# adversarial loss at step 9700: 0.7225168
# discriminator loss at step 9800: 0.6976593
# adversarial loss at step 9800: 0.6623368
# discriminator loss at step 9900: 0.6911213
# adversarial loss at step 9900: 0.74879277

# %%
import matplotlib.pyplot as plt

# Sample random points in the latent space
random_latent_vectors = np.random.normal(size=(10, latent_dim))

# Decode them to fake images
generated_images = generator.predict(random_latent_vectors)

for i in range(generated_images.shape[0]):
    img = image.array_to_img(generated_images[i] * 255., scale=False)
    plt.figure()
    plt.imshow(img)
    
plt.show()

# %% [markdown]
# # おまけ(2)：Descriminator(判別者)をよわよわにしてみた

# %%
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

# One dropout layer - important trick!
## 0.4>>0.7に変更
x = layers.Dropout(0.7)(x)

# Classification layer
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

# To stabilize training, we use learning rate decay
# and gradient clipping (by value) in the optimizer.
# lr 0.0008 > 0.00008に変更
discriminator_optimizer = keras.optimizers.RMSprop(lr=0.00008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
import os
from keras.preprocessing import image

# Load CIFAR10 data
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# Select frog images (class ２:鳥)
x_train = x_train[y_train.flatten() == 2]

# Normalize data
x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32') / 255.

iterations = 10000
batch_size = 20
# !mkdir gan_images
save_dir = './gan_images/'

# Start training loop
start = 0
for step in range(iterations):
    # Sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Decode them to fake images
    generated_images = generator.predict(random_latent_vectors)

    # Combine them with real images
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])

    # Assemble labels discriminating real from fake images
    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    # Add random noise to the labels - important trick!
    labels += 0.05 * np.random.random(labels.shape)

    # Train the discriminator
    d_loss = discriminator.train_on_batch(combined_images, labels)

    # sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Assemble labels that say "all real images"
    misleading_targets = np.zeros((batch_size, 1))

    # Train the generator (via the gan model,
    # where the discriminator weights are frozen)
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    
    start += batch_size
    if start > len(x_train) - batch_size:
      start = 0

    # Occasionally save / plot
    if step % 100 == 0:
        # Save model weights
        gan.save_weights('gan.h5')

        # Print metrics
        print('discriminator loss at step %s: %s' % (step, d_loss))
        print('adversarial loss at step %s: %s' % (step, a_loss))

        # Save one generated image
        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'generated_bird' + str(step) + '.png'))

        # Save one real image, for comparison
        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'real_bird' + str(step) + '.png'))
# Out:
# mkdir: cannot create directory ‘gan_images’: File exists
# discriminator loss at step 0: 0.69272333
# adversarial loss at step 0: 0.7132783
# discriminator loss at step 100: -0.19690847
# adversarial loss at step 100: 0.029977549
# discriminator loss at step 200: -0.16056733
# adversarial loss at step 200: 0.012588236
# discriminator loss at step 300: -0.08237162
# adversarial loss at step 300: 0.021653185
# discriminator loss at step 400: -0.1521075
# adversarial loss at step 400: 0.010062173
# discriminator loss at step 500: -0.15720893
# adversarial loss at step 500: 0.008303991
# discriminator loss at step 600: -0.13788593
# adversarial loss at step 600: 0.02241674
# discriminator loss at step 700: -0.15697213
# adversarial loss at step 700: 0.016428832
# discriminator loss at step 800: -0.18364815
# adversarial loss at step 800: 0.0042871376
# discriminator loss at step 900: -0.06256522
# adversarial loss at step 900: 0.00823799
# discriminator loss at step 1000: -0.1339359
# adversarial loss at step 1000: 0.0052144984
# discriminator loss at step 1100: -0.14640304
# adversarial loss at step 1100: 0.0017273456
# discriminator loss at step 1200: -0.14565592
# adversarial loss at step 1200: 0.008205714
# discriminator loss at step 1300: -0.12514153
# adversarial loss at step 1300: 0.0039743506
# discriminator loss at step 1400: -0.1506751
# adversarial loss at step 1400: 0.0046117245
# discriminator loss at step 1500: -0.17042336
# adversarial loss at step 1500: 0.006113676
# discriminator loss at step 1600: -0.16031186
# adversarial loss at step 1600: 0.007813873
# discriminator loss at step 1700: -0.13221271
# adversarial loss at step 1700: 0.0028993343
# discriminator loss at step 1800: -0.16944262
# adversarial loss at step 1800: 0.01024672
# discriminator loss at step 1900: -0.12254908
# adversarial loss at step 1900: 0.013643843
# discriminator loss at step 2000: -0.17285512
# adversarial loss at step 2000: 0.0036248404
# discriminator loss at step 2100: -0.19294384
# adversarial loss at step 2100: 0.004764153
# discriminator loss at step 2200: -0.12279081
# adversarial loss at step 2200: 0.012098658
# discriminator loss at step 2300: -0.15719469
# adversarial loss at step 2300: 0.0033897802
# discriminator loss at step 2400: -0.12744825
# adversarial loss at step 2400: 0.00370524
# discriminator loss at step 2500: -0.14291641
# adversarial loss at step 2500: 0.0087170685
# discriminator loss at step 2600: -0.10549544
# adversarial loss at step 2600: 0.004130031
# discriminator loss at step 2700: -0.15880139
# adversarial loss at step 2700: 0.0021101178
# discriminator loss at step 2800: -0.13530405
# adversarial loss at step 2800: 0.0024539668
# discriminator loss at step 2900: -0.11150922
# adversarial loss at step 2900: 0.001892017
# discriminator loss at step 3000: -0.15252218
# adversarial loss at step 3000: 0.004612034
# discriminator loss at step 3100: -0.18288288
# adversarial loss at step 3100: 0.0028043252
# discriminator loss at step 3200: -0.11871213
# adversarial loss at step 3200: 0.0036595087
# discriminator loss at step 3300: -0.11857426
# adversarial loss at step 3300: 0.00343742
# discriminator loss at step 3400: -0.15673155
# adversarial loss at step 3400: 0.00555184
# discriminator loss at step 3500: -0.1571783
# adversarial loss at step 3500: 0.0075292736
# discriminator loss at step 3600: -0.1470774
# adversarial loss at step 3600: 0.0042261938
# discriminator loss at step 3700: -0.13360444
# adversarial loss at step 3700: 0.002259159
# discriminator loss at step 3800: -0.14797327
# adversarial loss at step 3800: 0.00269183
# discriminator loss at step 3900: -0.1836239
# adversarial loss at step 3900: 0.0018193905
# discriminator loss at step 4000: -0.14070882
# adversarial loss at step 4000: 0.0019897907
# discriminator loss at step 4100: -0.13555878
# adversarial loss at step 4100: 0.0040202523
# discriminator loss at step 4200: -0.19156012
# adversarial loss at step 4200: 0.004497517
# discriminator loss at step 4300: -0.13907343
# adversarial loss at step 4300: 0.0057362486
# discriminator loss at step 4400: -0.16241786
# adversarial loss at step 4400: 0.0054469025
# discriminator loss at step 4500: -0.1863955
# adversarial loss at step 4500: 0.0019642115
# discriminator loss at step 4600: -0.12408078
# adversarial loss at step 4600: 0.0046821013
# discriminator loss at step 4700: -0.13226779
# adversarial loss at step 4700: 0.0040715495
# discriminator loss at step 4800: -0.10438921
# adversarial loss at step 4800: 0.005469423
# discriminator loss at step 4900: -0.16282523
# adversarial loss at step 4900: 0.0052610235
# discriminator loss at step 5000: -0.14606163
# adversarial loss at step 5000: 0.003583376
# discriminator loss at step 5100: -0.14674261
# adversarial loss at step 5100: 0.0035101876
# discriminator loss at step 5200: -0.10059645
# adversarial loss at step 5200: 0.0050782287
# discriminator loss at step 5300: -0.14693195
# adversarial loss at step 5300: 0.010851609
# discriminator loss at step 5400: -0.10496616
# adversarial loss at step 5400: 0.002236301
# discriminator loss at step 5500: -0.10329585
# adversarial loss at step 5500: 0.00593225
# discriminator loss at step 5600: -0.15620962
# adversarial loss at step 5600: 0.0046267225
# discriminator loss at step 5700: -0.14911519
# adversarial loss at step 5700: 0.004806052
# discriminator loss at step 5800: -0.1606187
# adversarial loss at step 5800: 0.004888425
# discriminator loss at step 5900: -0.17481953
# adversarial loss at step 5900: 0.004854024
# discriminator loss at step 6000: -0.10471469
# adversarial loss at step 6000: 0.0051303557
# discriminator loss at step 6100: -0.15030722
# adversarial loss at step 6100: 0.007872696
# discriminator loss at step 6200: -0.09857801
# adversarial loss at step 6200: 0.005308134
# discriminator loss at step 6300: -0.17977338
# adversarial loss at step 6300: 0.0039083357
# discriminator loss at step 6400: -0.117137626
# adversarial loss at step 6400: 0.0043491228
# discriminator loss at step 6500: -0.17061795
# adversarial loss at step 6500: 0.0025111535
# discriminator loss at step 6600: -0.17743833
# adversarial loss at step 6600: 0.004152161
# discriminator loss at step 6700: -0.116876855
# adversarial loss at step 6700: 0.008200649
# discriminator loss at step 6800: -0.17151621
# adversarial loss at step 6800: 0.005165105
# discriminator loss at step 6900: -0.14281437
# adversarial loss at step 6900: 0.0048661674
# discriminator loss at step 7000: -0.12718531
# adversarial loss at step 7000: 0.0051383465
# discriminator loss at step 7100: -0.08507121
# adversarial loss at step 7100: 0.010731831
# discriminator loss at step 7200: -0.104652725
# adversarial loss at step 7200: 0.0061657066
# discriminator loss at step 7300: -0.13185874
# adversarial loss at step 7300: 0.001997085
# discriminator loss at step 7400: -0.15638497
# adversarial loss at step 7400: 0.0040909657
# discriminator loss at step 7500: -0.1590476
# adversarial loss at step 7500: 0.0041931267
# discriminator loss at step 7600: -0.14705816
# adversarial loss at step 7600: 0.004033661
# discriminator loss at step 7700: -0.14153239
# adversarial loss at step 7700: 0.0043552937
# discriminator loss at step 7800: -0.16003531
# adversarial loss at step 7800: 0.0043312428
# discriminator loss at step 7900: -0.07673429
# adversarial loss at step 7900: 0.00823133
# discriminator loss at step 8000: -0.15319383
# adversarial loss at step 8000: 0.0021336786
# discriminator loss at step 8100: -0.1417058
# adversarial loss at step 8100: 0.0058581308
# discriminator loss at step 8200: -0.11314599
# adversarial loss at step 8200: 0.0026925479
# discriminator loss at step 8300: -0.15868896
# adversarial loss at step 8300: 0.0035275132
# discriminator loss at step 8400: -0.09353876
# adversarial loss at step 8400: 0.0033346687
# discriminator loss at step 8500: -0.1501077
# adversarial loss at step 8500: 0.0036601997
# discriminator loss at step 8600: -0.14322391
# adversarial loss at step 8600: 0.002153467
# discriminator loss at step 8700: -0.10961945
# adversarial loss at step 8700: 0.0043244837
# discriminator loss at step 8800: -0.12323941
# adversarial loss at step 8800: 0.002387136
# discriminator loss at step 8900: -0.14052045
# adversarial loss at step 8900: 0.0030923828
# discriminator loss at step 9000: -0.13920449
# adversarial loss at step 9000: 0.005032384
# discriminator loss at step 9100: -0.13591222
# adversarial loss at step 9100: 0.0025270628
# discriminator loss at step 9200: -0.10889824
# adversarial loss at step 9200: 0.0033227068
# discriminator loss at step 9300: -0.10854633
# adversarial loss at step 9300: 0.0034810654
# discriminator loss at step 9400: -0.1566272
# adversarial loss at step 9400: 0.0017753424
# discriminator loss at step 9500: -0.1247278
# adversarial loss at step 9500: 0.0036673069
# discriminator loss at step 9600: -0.16317149
# adversarial loss at step 9600: 0.0030538584
# discriminator loss at step 9700: -0.12846416
# adversarial loss at step 9700: 0.0072036684
# discriminator loss at step 9800: -0.14258811
# adversarial loss at step 9800: 0.0041188095
# discriminator loss at step 9900: -0.1537229
# adversarial loss at step 9900: 0.0030586936

# %%
import matplotlib.pyplot as plt

# Sample random points in the latent space
random_latent_vectors = np.random.normal(size=(10, latent_dim))

# Decode them to fake images
generated_images = generator.predict(random_latent_vectors)

for i in range(generated_images.shape[0]):
    img = image.array_to_img(generated_images[i] * 255., scale=False)
    plt.figure()
    plt.imshow(img)
    
plt.show()
